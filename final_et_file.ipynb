# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\hp pc\gl-practice sets\ensemble techniques project\Data - Parkinsons",delimiter=",")

# %%
data
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
data.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
#from sklearn.model_selection import train_test_split

X = data.drop('status',axis=1)     
Y = data['status']  

#x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
data.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %%
corvar = data.corr()
fig, ax = plt.subplots(figsize=(25,15))
sns.heatmap(corvar,annot=True,square=True)
plt.xticks(range(len(corvar.columns)), corvar.columns,rotation=90)
plt.yticks(range(len(corvar.columns)), corvar.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x2181d022a00>,
# ...
#  [Text(0, 0, 'MDVP:Fo(Hz)'),
#   Text(0, 1, 'MDVP:Fhi(Hz)'),
#   Text(0, 2, 'MDVP:Flo(Hz)'),
#   Text(0, 3, 'MDVP:Jitter(%)'),
#   Text(0, 4, 'MDVP:Jitter(Abs)'),
#   Text(0, 5, 'MDVP:RAP'),
#   Text(0, 6, 'MDVP:PPQ'),
#   Text(0, 7, 'Jitter:DDP'),
#   Text(0, 8, 'MDVP:Shimmer'),
#   Text(0, 9, 'MDVP:Shimmer(dB)'),
#   Text(0, 10, 'Shimmer:APQ3'),
#   Text(0, 11, 'Shimmer:APQ5'),
#   Text(0, 12, 'MDVP:APQ'),
#   Text(0, 13, 'Shimmer:DDA'),
#   Text(0, 14, 'NHR'),
#   Text(0, 15, 'HNR'),
#   Text(0, 16, 'status'),
#   Text(0, 17, 'RPDE'),
#   Text(0, 18, 'DFA'),
#   Text(0, 19, 'spread1'),
#   Text(0, 20, 'spread2'),
#   Text(0, 21, 'D2'),
#   Text(0, 22, 'PPE')])

# %%
#pretty strong relations of 
#sns.pairplot(data,diag_kind='kde')
data.head(20)
# Out:
#               name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0   phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1   phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2   phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3   phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4   phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5   phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6   phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7   phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8   phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9   phon_R01_S02_4       95.056       120.103        91.226         0.00532
# 10  phon_R01_S02_5       88.333       112.240        84.072         0.00505
# ...

# %% [markdown]
# Simplifying names to numbers

# %%
#for i in data.name:
    #print(i)
z=0
for j in range(1,51):
    
    for i in data.name:
        if j<=9:
            if ('_S0'+str(j)+'_' in str(i)):
                data.name.loc[data.name==i]=str(j)
                
                
                
                
                
        if j>9:
            if ('_S'+str(j)+'_' in str(i)):
                data.name.loc[data.name==i]=str(j)
# Out:
# C:\Users\hp pc\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
data.name=data.name.astype('int64')

# %%
data.name.dtypes
# Out:
# dtype('int64')

# %%
data1=data.iloc[:,4:9]
data1['status']=data.iloc[:,17]
sns.pairplot(data1)

# %%
corvar1 = data1.corr()
fig, ax = plt.subplots(figsize=(25,15))
sns.heatmap(corvar1,annot=True,square=True)
plt.xticks(range(len(corvar1.columns)), corvar1.columns,rotation=90)
plt.yticks(range(len(corvar1.columns)), corvar1.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x2181ee0d790>,
# ...
#  [Text(0, 0, 'MDVP:Jitter(%)'),
#   Text(0, 1, 'MDVP:Jitter(Abs)'),
#   Text(0, 2, 'MDVP:RAP'),
#   Text(0, 3, 'MDVP:PPQ'),
#   Text(0, 4, 'Jitter:DDP'),
#   Text(0, 5, 'status')])

# %% [markdown]
# # Pretty strong correlations here-maximum of MDVP:Jitter(abs) with status.
# #Great correlation between Jitter:DDP and MDVP:RAP; strong enough to drop one of these.
# #Another pair for great correlation-MDVP:RAP & MDVP(Jitter %),Jitter DDP & MDVP:Jitter(%).

# %%
data1.corr()
# Out:
#                   MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  \
# MDVP:Jitter(%)          1.000000          0.935714  0.990276  0.974256
# MDVP:Jitter(Abs)        0.935714          1.000000  0.922911  0.897778
# MDVP:RAP                0.990276          0.922911  1.000000  0.957317
# MDVP:PPQ                0.974256          0.897778  0.957317  1.000000
# Jitter:DDP              0.990276          0.922913  1.000000  0.957319
# status                  0.278220          0.338653  0.266668  0.288698
#
#                   Jitter:DDP    status
# MDVP:Jitter(%)      0.990276  0.278220
# MDVP:Jitter(Abs)    0.922913  0.338653
# MDVP:RAP            1.000000  0.266668
# MDVP:PPQ            0.957319  0.288698
# Jitter:DDP          1.000000  0.266646
# status              0.266646  1.000000

# %% [markdown]
# Jitter:Abs dropped-lesser correlation than Jitter:%
# MDVP:RAP and MDVP:PPQ-dropped-strong correlation with Jitter Abs and a weaker correlation with Status.

# %%
data.drop(['MDVP:Jitter(%)','MDVP:RAP','MDVP:PPQ'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)',
#        'MDVP:Jitter(Abs)', 'Jitter:DDP', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)',
#        'Shimmer:APQ3', 'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR',
#        'status', 'RPDE', 'DFA', 'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
data2=data.iloc[:,9:14]
data2['Shimmer:DDA']=data.iloc[:,14]
data2['status']=data.iloc[:,17]
data2.corr()
# Out:
#               Shimmer:APQ5  MDVP:APQ  Shimmer:DDA       NHR       HNR  \
# Shimmer:APQ5      1.000000  0.949146     0.351148  0.658080 -0.813753
# MDVP:APQ          0.949146  1.000000     0.364316  0.694019 -0.800407
# Shimmer:DDA       0.351148  0.364316     1.000000  0.189429 -0.361515
# NHR               0.658080  0.694019     0.189429  1.000000 -0.714072
# HNR              -0.813753 -0.800407    -0.361515 -0.714072  1.000000
# status            0.646809  0.673158     0.564838  0.540865 -0.673210
#
#                 status
# Shimmer:APQ5  0.646809
# MDVP:APQ      0.673158
# Shimmer:DDA   0.564838
# NHR           0.540865
# HNR          -0.673210
# status        1.000000

# %% [markdown]
# For every pair in above table where correlation value>.95; we try and drop one of them.
# Jitter(abs) is dropped off

# %% [markdown]
# we drop either of Shimmer:APQ3 and Shimmer:APQ5 ;however Shimmer APQ5 has a stronger correlation with status.
# MDVP:Shimmer(dB) is dropped out of MDVP:Shimmer and MDVP:Shimmer(dB)-since it has a weaker correlation with status.
# all the others are retained.

# %%
data.drop(['MDVP:Shimmer(dB)','Shimmer:APQ3'],axis=1,inplace=True)
data
# Out:
#      name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(Abs)  \
# 0       1      119.992       157.302        74.997           0.00007
# 1       1      122.400       148.650       113.819           0.00008
# 2       1      116.682       131.111       111.555           0.00009
# 3       1      116.676       137.871       111.366           0.00009
# 4       1      116.014       141.781       110.655           0.00011
# ..    ...          ...           ...           ...               ...
# 190    50      174.188       230.978        94.261           0.00003
# 191    50      209.516       253.017        89.488           0.00003
# 192    50      174.688       240.005        74.287           0.00008
# 193    50      198.764       396.961        74.904           0.00004
# 194    50      214.289       260.277        77.973           0.00003
#
#      Jitter:DDP  MDVP:Shimmer  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA      NHR  \
# ...

# %%
fig=plt.figure(figsize=(15,10))
for i,col in enumerate(data1.columns):
    ax=fig.add_subplot(2,3,i+1)
    sns.histplot(data1[col])

# %% [markdown]
# Almost all of them are positively skewed.

# %%
fig=plt.figure(figsize=(15,10))
for i,col in enumerate(data2.columns):
    ax=fig.add_subplot(2,3,i+1)
    sns.histplot(data2[col])

# %% [markdown]
# Jitter(%) dropped out of Jitter(%) and Jitter(abs)
# MDVP:RAP dropped
# all except for HNR seem positively skewed.

# %%
data.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)',
#        'MDVP:Jitter(Abs)', 'Jitter:DDP', 'MDVP:Shimmer', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
data3=data.iloc[:,15:17]
data3['PPE']=data.iloc[:,18]
data3['status']=data.iloc[:,12]

data3=pd.concat((data3,data.iloc[:,1:4]),axis=1)
data3
# Out:
#       spread1   spread2       PPE  status  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  \
# 0   -4.813031  0.266482  0.284654       1      119.992       157.302
# 1   -4.075192  0.335590  0.368674       1      122.400       148.650
# 2   -4.443179  0.311173  0.332634       1      116.682       131.111
# 3   -4.117501  0.334147  0.368975       1      116.676       137.871
# 4   -3.747787  0.234513  0.410335       1      116.014       141.781
# ..        ...       ...       ...     ...          ...           ...
# 190 -6.538586  0.121952  0.133050       0      174.188       230.978
# 191 -6.195325  0.129303  0.168895       0      209.516       253.017
# 192 -6.787197  0.158453  0.131728       0      174.688       240.005
# 193 -6.744577  0.207454  0.123306       0      198.764       396.961
# 194 -5.724056  0.190667  0.148569       0      214.289       260.277
#
#      MDVP:Flo(Hz)
# 0          74.997
# 1         113.819
# 2         111.555
# 3         111.366
# 4         110.655
# ..            ...
# ...

# %% [markdown]
# all have considerable correlation amongst themselves and with status
# hence retained

# %%
data3.corr()
# Out:
#                spread1   spread2       PPE    status  MDVP:Fo(Hz)  \
# spread1       1.000000  0.652358  0.962435  0.564838    -0.413738
# spread2       0.652358  1.000000  0.644711  0.454842    -0.249450
# PPE           0.962435  0.644711  1.000000  0.531039    -0.372356
# status        0.564838  0.454842  0.531039  1.000000    -0.383535
# MDVP:Fo(Hz)  -0.413738 -0.249450 -0.372356 -0.383535     1.000000
# MDVP:Fhi(Hz) -0.076658 -0.002954 -0.069543 -0.166136     0.400985
# MDVP:Flo(Hz) -0.394857 -0.243829 -0.340071 -0.380200     0.596546
#
#               MDVP:Fhi(Hz)  MDVP:Flo(Hz)
# spread1          -0.076658     -0.394857
# spread2          -0.002954     -0.243829
# PPE              -0.069543     -0.340071
# status           -0.166136     -0.380200
# MDVP:Fo(Hz)       0.400985      0.596546
# MDVP:Fhi(Hz)      1.000000      0.084951
# MDVP:Flo(Hz)      0.084951      1.000000

# %%
sns.histplot( data[data.status == 0]['MDVP:Fhi(Hz)'], color = 'r',)
sns.histplot( data[data.status == 1]['MDVP:Fhi(Hz)'], color = 'g')
# Out:
# <AxesSubplot:xlabel='MDVP:Fhi(Hz)', ylabel='Count'>

# %%
sns.histplot( data[data.status == 0]['MDVP:Flo(Hz)'], color = 'r',)
sns.histplot( data[data.status == 1]['MDVP:Flo(Hz)'], color = 'g')
# Out:
# <AxesSubplot:xlabel='MDVP:Flo(Hz)', ylabel='Count'>

# %%
sns.histplot( data[data.status == 0]['MDVP:Fhi(Hz)'], color = 'r',)
sns.histplot( data[data.status == 1]['MDVP:Fhi(Hz)'], color = 'g')
# Out:
# <AxesSubplot:xlabel='MDVP:Fhi(Hz)', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='MDVP:Flo(Hz)',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='MDVP:Flo(Hz)'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='MDVP:Fhi(Hz)',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='MDVP:Fhi(Hz)'>

# %% [markdown]
# There is no clear boundary of frequency between healthy and normal people.(when maximum fundamental and minimum fundamental frequency are taken into account)

# %%
sns.histplot( data[data.status == 0]['MDVP:Jitter(Abs)'], color = 'r')
sns.histplot( data[data.status == 1]['MDVP:Jitter(Abs)'], color = 'g')
# Out:
# <AxesSubplot:xlabel='MDVP:Jitter(Abs)', ylabel='Count'>

# %%
sns.histplot( data[data.status == 0]['spread1'], color = 'r',)
sns.histplot( data[data.status == 1]['spread1'], color = 'g')
# Out:
# <AxesSubplot:xlabel='spread1', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='spread1',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='spread1'>

# %%
sns.histplot( data[data.status == 0]['spread2'], color = 'r',)
sns.histplot( data[data.status == 1]['spread2'], color = 'g')
# Out:
# <AxesSubplot:xlabel='spread2', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='spread2',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='spread2'>

# %%
sns.histplot( data[data.status == 0]['PPE'], color = 'r',)
sns.histplot( data[data.status == 1]['PPE'], color = 'g')
# Out:
# <AxesSubplot:xlabel='PPE', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='PPE',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='PPE'>

# %% [markdown]
# PPE of healthy people end near the median of PPE of people with Parkinsons(at around 0.2)
#
# People with PPE value > 0.2 have high probability of having parkinson's deisease.

# %%
sns.histplot( data[data.status == 0]['MDVP:Jitter(Abs)'], color = 'r',)
sns.histplot( data[data.status == 1]['MDVP:Jitter(Abs)'], color = 'g')
# Out:
# <AxesSubplot:xlabel='MDVP:Jitter(Abs)', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='MDVP:Jitter(Abs)',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='MDVP:Jitter(Abs)'>

# %%
sns.histplot(data[data.status == 0]['Jitter:DDP'], color = 'r')
sns.histplot(data[data.status == 1]['Jitter:DDP'], color = 'g')
# Out:
# <AxesSubplot:xlabel='Jitter:DDP', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='Jitter:DDP',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='Jitter:DDP'>

# %% [markdown]
# 1.In all the measures of variation in fundamental frequency, people having parkinson disease have a considerably wider range.
# 2.But in the lower ranges of frequencies, there is complete overlap over each other for both types of individuals.
# 3.Very high peaks(almost three-fold to that of people with parkinson at the peak frequency), with low dispersion can be seen in case of healthy individuals.

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
sns.histplot(data['MDVP:Shimmer'],ax=axes[0,0])
sns.histplot(data['Shimmer:APQ5'],ax=axes[0,1])
sns.histplot(data['MDVP:APQ'],ax=axes[1,0])
sns.histplot(data['Shimmer:DDA'],ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='Shimmer:DDA', ylabel='Count'>

# %% [markdown]
# All positively skewed.

# %%
sns.histplot(data[data.status == 0]['MDVP:Shimmer'], color = 'r')
sns.histplot(data[data.status == 1]['MDVP:Shimmer'], color = 'g')
# Out:
# <AxesSubplot:xlabel='MDVP:Shimmer', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='MDVP:Shimmer',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='MDVP:Shimmer'>

# %%
sns.histplot(data[data.status == 0]['Shimmer:APQ5'], color = 'r')
sns.histplot(data[data.status == 1]['Shimmer:APQ5'], color = 'g')
# Out:
# <AxesSubplot:xlabel='Shimmer:APQ5', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='Shimmer:APQ5',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='Shimmer:APQ5'>

# %%
sns.histplot(data[data.status == 0]['Shimmer:DDA'], color = 'r')
sns.histplot(data[data.status == 1]['Shimmer:DDA'], color = 'g')
# Out:
# <AxesSubplot:xlabel='Shimmer:DDA', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='Shimmer:DDA',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='Shimmer:DDA'>

# %%
sns.histplot(data[data.status == 0]['MDVP:APQ'], color = 'r')
sns.histplot(data[data.status == 1]['MDVP:APQ'], color = 'g')
# Out:
# <AxesSubplot:xlabel='MDVP:APQ', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='MDVP:APQ',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='MDVP:APQ'>

# %% [markdown]
# 1.In all the measures of variation in amplitude, people having parkinson disease have a considerably wider range.
# 2.But in the lower ranges of amplitudes, there is complete overlap over each other for both types of individuals.
# 3.Very high peaks(almost three-fold to that of people with parkinson at the peak amplitude), with low dispersion can be seen in case of healthy individuals.

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,8))
sns.histplot(data['RPDE'],ax=axes[0])
sns.histplot(data['D2'],ax=axes[1])
# Out:
# <AxesSubplot:xlabel='D2', ylabel='Count'>

# %% [markdown]
# Distribution of D2 almost resembles normal distribution. Distribution of RPDE is positively skewed.

# %%
sns.histplot(data[data.status == 0]['RPDE'], color = 'r')
sns.histplot(data[data.status == 1]['RPDE'], color = 'g')
# Out:
# <AxesSubplot:xlabel='RPDE', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='RPDE',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='RPDE'>

# %%
sns.histplot(data[data.status == 0]['D2'], color = 'r')
sns.histplot(data[data.status == 1]['D2'], color = 'g')
# Out:
# <AxesSubplot:xlabel='D2', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='D2',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='D2'>

# %% [markdown]
# Peak of distribution is very close and dispersion range very similar in case of both individuals

# %%
sns.histplot(data[data.status == 0]['HNR'], color = 'r')
sns.histplot(data[data.status == 1]['HNR'], color = 'g')
# Out:
# <AxesSubplot:xlabel='HNR', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='HNR',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='HNR'>

# %%
sns.histplot(data[data.status == 0]['NHR'], color = 'r')
sns.histplot(data[data.status == 1]['NHR'], color = 'g')
# Out:
# <AxesSubplot:xlabel='NHR', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='status',y='NHR',data=data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='NHR'>

# %% [markdown]
# Individuals with HNR < 20, have higher probability of having parkinson's disease

# %% [markdown]
# Splitting dataset

# %%
X = data.drop(['status'], axis = 1)
y = data['status']
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=1)

# %% [markdown]
# Scaling dataset

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler().fit(X_train)
scaler_x_train=scaler.transform(X_train)

scaler=StandardScaler().fit(X_test)
scaler_x_test=scaler.transform(X_test)

# %% [markdown]
# Model metrics calculation

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

def clf_scores(clf,y_predicted):
    #Accuracy
    acc_train = clf.score(X_train, y_train)*100
    acc_test = clf.score(X_test, y_test)*100
    
    roc = roc_auc_score(y_test, y_predicted)*100
    tn, fp, fn, tp = confusion_matrix(y_test, y_predicted).ravel()
    cm = confusion_matrix(y_test, y_predicted)
    correct = tp + tn
    incorrect = fp + fn
        
    return acc_train, acc_test, roc, correct, incorrect, cm

def clf_table(clf,y_predicted):
    cr=classification_report(y_test,y_predicted, digits=2)
    return cr

# %%
performance = pd.DataFrame(columns = ['Model', 'Accuracy', 'Recall', 'Precision', 'F1 Score', 'AUC'])

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf_lr = LogisticRegression()
clf_lr.fit(X_train, y_train)

Y_pred_lr = clf_lr.predict(X_test)
print(clf_scores(clf_lr, Y_pred_lr))
# Out:
# (89.70588235294117, 84.7457627118644, 77.69736842105263, 50, 9, array([[11,  8],
#        [ 1, 39]], dtype=int64))
# C:\Users\hp pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn import preprocessing
from sklearn.metrics import average_precision_score, confusion_matrix, accuracy_score, classification_report,f1_score

cr1= clf_table(clf_lr, Y_pred_lr)
print(cr1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.58      0.71        19
#            1       0.83      0.97      0.90        40
#
#     accuracy                           0.85        59
#    macro avg       0.87      0.78      0.80        59
# weighted avg       0.86      0.85      0.84        59

# %%
from sklearn import metrics
#determining ROC-AUC using fpr, tpr, threshold
fpr, tpr, threshold = metrics.roc_curve(y_test, Y_pred_lr)
roc_auc_stack = metrics.auc(fpr, tpr)
print("AUC : % 1.4f" %(roc_auc_stack))
# Out:
# AUC :  0.7770

# %%
performance = performance.append({'Model':'Logistic Regression','Accuracy':'85','Recall':'97','Precision':'83','F1 Score':'90','AUC':'77.7'},ignore_index = True)

# %% [markdown]
# Precison-83%
# Recall-97%
# f1-score-90%
# accuracy=85%

# %% [markdown]
# KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
clf_knn = KNeighborsClassifier(n_neighbors = 3)
clf_knn.fit(X_train, y_train)

Y_pred_knn = clf_knn.predict(X_test)
print(clf_scores(clf_knn, Y_pred_knn))
# Out:
# (94.85294117647058, 86.4406779661017, 80.32894736842104, 51, 8, array([[12,  7],
#        [ 1, 39]], dtype=int64))

# %%
cr2 =clf_table(y_test,Y_pred_knn)
print(cr2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.63      0.75        19
#            1       0.85      0.97      0.91        40
#
#     accuracy                           0.86        59
#    macro avg       0.89      0.80      0.83        59
# weighted avg       0.87      0.86      0.86        59

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, Y_pred_knn)
roc_auc_stack = metrics.auc(fpr, tpr)
print("AUC : % 1.4f" %(roc_auc_stack))
# Out:
# AUC :  0.8033

# %% [markdown]
# Precision-85%
# Recall-97%
# f1-score-91%
# Accuracy-86%

# %%
performance = performance.append({'Model':'KNN','Accuracy':'86','Recall':'97','Precision':'85','F1 Score':'91','AUC':'80.3'},ignore_index = True)

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
clf_gnb = GaussianNB()
clf_gnb.fit(X_train, y_train)

Y_pred_gnb = clf_gnb.predict(X_test)
print(clf_scores(clf_gnb, Y_pred_gnb))
# Out:
# (73.52941176470588, 74.57627118644068, 78.48684210526315, 44, 15, array([[17,  2],
#        [13, 27]], dtype=int64))

# %%
cr3=clf_table(y_test,Y_pred_gnb)
print(cr3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.89      0.69        19
#            1       0.93      0.68      0.78        40
#
#     accuracy                           0.75        59
#    macro avg       0.75      0.78      0.74        59
# weighted avg       0.81      0.75      0.75        59

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, Y_pred_gnb)
roc_auc_stack = metrics.auc(fpr, tpr)
print("AUC : % 1.4f" %(roc_auc_stack))
# Out:
# AUC :  0.7849

# %% [markdown]
# Precision-93%
# Recall-68%
# f1-score-78%
# Accuracy-75%

# %%
performance = performance.append({'Model':'Naive Bayes','Accuracy':'75','Recall':'68','Precision':'93','F1 Score':'78','AUC':'78.49'},ignore_index = True)

# %% [markdown]
# SVM

# %%
from sklearn import svm
clf = svm.SVC(gamma=0.025, C=3)
clf.fit(X_train , y_train)
y_pred_sv = clf.predict(X_test)

# %%
cr4=clf_table(y_test,y_pred_sv)
print(cr4)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.37      0.54        19
#            1       0.77      1.00      0.87        40
#
#     accuracy                           0.80        59
#    macro avg       0.88      0.68      0.70        59
# weighted avg       0.84      0.80      0.76        59

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred_sv)
roc_auc_stack = metrics.auc(fpr, tpr)
print("AUC : % 1.4f" %(roc_auc_stack))
# Out:
# AUC :  0.6842

# %%
performance = performance.append({'Model':'SVM','Accuracy':'80','Recall':'100','Precision':'77','F1 Score':'87','AUC':'68.4'},ignore_index = True)

# %% [markdown]
# Out of the above four,KNN has well balanced values of performance parameters;it performs best.

# %%
print(performance)
# Out:
#                  Model Accuracy Recall Precision F1 Score    AUC
# 0  Logistic Regression       85     97        83       90   77.7
# 1                  KNN       86     97        85       91   80.3
# 2          Naive Bayes       75     68        93       78  78.49
# 3                  SVM       80    100        77       87   68.4

# %% [markdown]
# Training a meta-classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import StackingClassifier

# %%
# defining level hetrogeneous model
level0 = list()
level0.append(('lr', LogisticRegression()))
level0.append(('knn', KNeighborsClassifier(n_neighbors = 29, weights = 'uniform', metric='euclidean')))
level0.append(('cart', DecisionTreeClassifier()))
level0.append(('svm', svm.SVC(gamma=0.05, C=3)))
level0.append(('bayes', GaussianNB()))

# %%
#meta learner model
level1 = svm.SVC(gamma=0.05, C=3)

# %%
# define the stacking ensemble with cross validation of 10
Stack_model = StackingClassifier(estimators=level0, final_estimator=level1, cv=10)

# %%
# predict the response
Stack_model.fit(scaler_x_train, y_train)
prediction_Stack = Stack_model.predict(scaler_x_test)
cr5 = clf_table(Stack_model, prediction_Stack)
print(cr5)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82        19
#            1       0.89      0.97      0.93        40
#
#     accuracy                           0.90        59
#    macro avg       0.91      0.86      0.88        59
# weighted avg       0.90      0.90      0.89        59

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, prediction_Stack)
roc_auc_stack = metrics.auc(fpr, tpr)
print("AUC : % 1.4f" %(roc_auc_stack))
# Out:
# AUC :  0.8559

# %%
performance = performance.append({'Model':'Stacking:SVM','Accuracy':'90','Recall':'97','Precision':'89','F1 Score':'93','AUC':'85.59'},ignore_index = True)

# %%
#Stacking using Logistic reg. 
level1 = LogisticRegression()
Stack_model = StackingClassifier(estimators=level0, final_estimator=level1, cv=10)

# %%
Stack_model.fit(scaler_x_train, y_train)
prediction_Stack = Stack_model.predict(scaler_x_test)

# %%
print(clf_scores(Stack_model, prediction_Stack))
# Out:
# (78.67647058823529, 67.79661016949152, 84.21052631578947, 53, 6, array([[13,  6],
#        [ 0, 40]], dtype=int64))

# %%
cr6 = clf_table(Stack_model, prediction_Stack)
print(cr6)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81        19
#            1       0.87      1.00      0.93        40
#
#     accuracy                           0.90        59
#    macro avg       0.93      0.84      0.87        59
# weighted avg       0.91      0.90      0.89        59

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, prediction_Stack)
roc_auc_stack = metrics.auc(fpr, tpr)
print("AUC : % 1.4f" %(roc_auc_stack))
# Out:
# AUC :  0.8421

# %%
performance = performance.append({'Model':'Stacking:LG','Accuracy':'90','Recall':'100','Precision':'87','F1 Score':'93','AUC':'84.21'},ignore_index = True)

# %%
print(performance)
# Out:
#                  Model Accuracy Recall Precision F1 Score    AUC
# 0  Logistic Regression       85     97        83       90   77.7
# 1                  KNN       86     97        85       91   80.3
# 2          Naive Bayes       75     68        93       78  78.49
# 3                  SVM       80    100        77       87   68.4
# 4         Stacking:SVM       90     97        89       93  85.59
# 5          Stacking:LG       90    100        87       93  84.21

# %% [markdown]
# Here, the svm performs better as a stacking classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfcl = RandomForestClassifier(n_estimators = 50)
rfcl = rfcl.fit(X_train, y_train)
y_pred_rf = rfcl.predict(X_test)
print(clf_scores(rfcl, y_pred_rf))
# Out:
# (100.0, 94.91525423728814, 92.10526315789474, 56, 3, array([[16,  3],
#        [ 0, 40]], dtype=int64))

# %%
cr7 = clf_table(rfcl, y_pred_rf)
print(cr7)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91        19
#            1       0.93      1.00      0.96        40
#
#     accuracy                           0.95        59
#    macro avg       0.97      0.92      0.94        59
# weighted avg       0.95      0.95      0.95        59

# %%
#determining ROC-AUC using fpr, tpr, threshold
fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred_rf)
roc_auc_stack = metrics.auc(fpr, tpr)
print("AUC : % 1.4f" %(roc_auc_stack))
# Out:
# AUC :  0.9211

# %%
performance = performance.append({'Model':'Random Forest','Accuracy':'95','Recall':'100','Precision':'93','F1 Score':'91','AUC':'92.11'},ignore_index = True)

# %% [markdown]
# Comparing models

# %%
print(performance)
# Out:
#                  Model Accuracy Recall Precision F1 Score    AUC
# 0  Logistic Regression       85     97        83       90   77.7
# 1                  KNN       86     97        85       91   80.3
# 2          Naive Bayes       75     68        93       78  78.49
# 3                  SVM       80    100        77       87   68.4
# 4         Stacking:SVM       90     97        89       93  85.59
# 5          Stacking:LG       90    100        87       93  84.21
# 6        Random Forest       93    100        92       96   83.3
# 7        Random Forest       95    100        93       91  92.11

# %%
performance.set_index("Model", inplace = True)
convert_dict = {'Accuracy': float, 'Recall': float,'Precision': float, 'F1 Score': float, 'AUC': float} 
summary = performance.astype(convert_dict)

# %%
plt.figure(figsize=(11,8))
sns.lineplot(data=summary)
# Out:
# <AxesSubplot:xlabel='Model'>

# %% [markdown]
# There's a peak mostly with the Stacking:SVM which stays constant with the Random Forest or in some cases(Accuracy,Precision...etc) even improves.
# Random Forest performs the best here.
